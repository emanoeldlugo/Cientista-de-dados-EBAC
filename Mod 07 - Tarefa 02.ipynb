# %% [markdown]
# # Módulo 07 - Tarefa 02
#
# #### 1) Carregue a base e garanta que a base está como deveria.
#
# Considere a base que você ajustou na lição passada. Carregue-a. Caso ainda haja alguma pendência, ajuste - lembre-se de que o scikitlearn não recebe variáveis em formato string, somente numéricas, e não aceita '*missings*'.
#
# - Separe 70% da base para treinamento e 30% para validação. Cada uma dessas partes terá dois objetos, um armazenando a variável resposta ```mau```e outro armazenando as variáveis explicativas (lembrando: sem variáveis string, já com as dummies).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('base_modulo_7.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 33 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   sexo                                      16650 non-null  int64
#  1   posse_de_veiculo                          16650 non-null  int64
#  2   posse_de_imovel                           16650 non-null  int64
#  3   qtd_filhos                                16650 non-null  int64
#  4   idade                                     16650 non-null  float64
#  5   tempo_emprego                             16650 non-null  float64
#  6   possui_celular                            16650 non-null  int64
#  7   possui_fone_comercial                     16650 non-null  int64
#  8   possui_fone                               16650 non-null  int64
#  9   possui_email                              16650 non-null  int64
#  10  qt_pessoas_residencia                     16650 non-null  float64
#  11  mau                                       16650 non-null  bool
#  12  tipo_renda_Pensioner                      16650 non-null  bool
#  13  tipo_renda_State servant                  16650 non-null  bool
#  14  tipo_renda_Student                        16650 non-null  bool
#  15  tipo_renda_Working                        16650 non-null  bool
#  16  educacao_Higher education                 16650 non-null  bool
#  17  educacao_Incomplete higher                16650 non-null  bool
#  18  educacao_Lower secondary                  16650 non-null  bool
#  19  educacao_Secondary / secondary special    16650 non-null  bool
#  20  estado_civil_Married                      16650 non-null  bool
#  21  estado_civil_Separated                    16650 non-null  bool
#  22  estado_civil_Single / not married         16650 non-null  bool
#  23  estado_civil_Widow                        16650 non-null  bool
#  24  tipo_residencia_House / apartment         16650 non-null  bool
#  25  tipo_residencia_Municipal apartment       16650 non-null  bool
#  26  tipo_residencia_Office apartment          16650 non-null  bool
#  27  tipo_residencia_Rented apartment          16650 non-null  bool
#  28  tipo_residencia_With parents              16650 non-null  bool
#  29  educacao_Higher education.1               16650 non-null  bool
#  30  educacao_Incomplete higher.1              16650 non-null  bool
#  31  educacao_Lower secondary.1                16650 non-null  bool
#  32  educacao_Secondary / secondary special.1  16650 non-null  bool
# dtypes: bool(22), float64(3), int64(8)
# memory usage: 1.7 MB

# %%
x = df.drop('mau', axis=1)
y = df['mau']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=100)

# %%
x_train.shape
# Out:
# (11655, 32)

# %%
y_train.shape
# Out:
# (11655,)

# %%
x_test.shape
# Out:
# (4995, 32)

# %%
y_test.shape
# Out:
# (4995,)

# %% [markdown]
# #### 2) Vamos para o modelo:
#
# 1. Defina um objeto com a função da árvore de decisão vista em aula.
# 2. Treine o modelo com os dados que você separou para treinamento.
# 3. Visualize a árvore. Talvez você queira aumentar um pouco a figura.
# 4. Produza uma visualização da matriz de classificação (ou matriz de confusão) - coloque os rótulos como "aprovados" e "reprovados" - pois afinal de contas, são essas as decisões que se podem tomar com propostas de crédito.
# 5. Calcule a acurácia na base de treinamento

# %%
clf = DecisionTreeClassifier(random_state=100)
clf = clf.fit(x_train, y_train)

# %%
plt.figure(figsize=(20,20))
plot_tree(clf,
          filled=True,
          class_names=['Aprovados', 'Reprovados'],
          feature_names=x.columns
          )
# Out:
# [Text(0.6236132008293561, 0.9814814814814815, 'tempo_emprego <= 2.848\ngini = 0.044\nsamples = 11655\nvalue = [11392, 263]\nclass = Aprovados'),
#  Text(0.3730788604833427, 0.9444444444444444, 'tempo_emprego <= 2.845\ngini = 0.059\nsamples = 4279\nvalue = [4149, 130]\nclass = Aprovados'),
#  Text(0.23736116472487367, 0.9074074074074074, 'idade <= 30.175\ngini = 0.058\nsamples = 4273\nvalue = [4145, 128]\nclass = Aprovados'),
#  Text(0.06513194834362718, 0.8703703703703703, 'educacao_Incomplete higher <= 0.5\ngini = 0.116\nsamples = 438\nvalue = [411, 27]\nclass = Aprovados'),
#  Text(0.049410443571027515, 0.8333333333333334, 'idade <= 30.137\ngini = 0.084\nsamples = 388\nvalue = [371, 17]\nclass = Aprovados'),
#  Text(0.035934868051656375, 0.7962962962962963, 'estado_civil_Single / not married <= 0.5\ngini = 0.071\nsamples = 381\nvalue = [367, 14]\nclass = Aprovados'),
#  Text(0.017967434025828188, 0.7592592592592593, 'tempo_emprego <= 0.693\ngini = 0.042\nsamples = 283\nvalue = [277, 6]\nclass = Aprovados'),
#  Text(0.011978289350552125, 0.7222222222222222, 'idade <= 24.782\ngini = 0.126\nsamples = 59\nvalue = [55, 4]\nclass = Aprovados'),
#  Text(0.008983717012914094, 0.6851851851851852, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.014972861688190155, 0.6851851851851852, 'qtd_filhos <= 0.5\ngini = 0.098\nsamples = 58\nvalue = [55, 3]\nclass = Aprovados'),
#  Text(0.011978289350552125, 0.6481481481481481, 'idade <= 29.156\ngini = 0.219\nsamples = 24\nvalue = [21, 3]\nclass = Aprovados'),
#  Text(0.008983717012914094, 0.6111111111111112, 'tipo_renda_Pensioner <= 0.5\ngini = 0.159\nsamples = 23\nvalue = [21, 2]\nclass = Aprovados'),
#  Text(0.0059891446752760626, 0.5740740740740741, 'tempo_emprego <= 0.658\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = Aprovados'),
#  Text(0.0029945723376380313, 0.5370370370370371, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = Aprovados'),
#  Text(0.008983717012914094, 0.5370370370370371, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Aprovados'),
#  Text(0.011978289350552125, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.014972861688190155, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.017967434025828188, 0.6481481481481481, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]\nclass = Aprovados'),
#  Text(0.02395657870110425, 0.7222222222222222, 'tempo_emprego <= 2.318\ngini = 0.018\nsamples = 224\nvalue = [222, 2]\nclass = Aprovados'),
#  Text(0.020962006363466217, 0.6851851851851852, 'gini = 0.0\nsamples = 174\nvalue = [174, 0]\nclass = Aprovados'),
#  Text(0.02695115103874228, 0.6851851851851852, 'tempo_emprego <= 2.356\ngini = 0.077\nsamples = 50\nvalue = [48, 2]\nclass = Aprovados'),
#  Text(0.02395657870110425, 0.6481481481481481, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.02994572337638031, 0.6481481481481481, 'possui_fone <= 0.5\ngini = 0.041\nsamples = 48\nvalue = [47, 1]\nclass = Aprovados'),
#  Text(0.02695115103874228, 0.6111111111111112, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]\nclass = Aprovados'),
#  Text(0.03294029571401834, 0.6111111111111112, 'possui_fone_comercial <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Aprovados'),
#  Text(0.02994572337638031, 0.5740740740740741, 'sexo <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.02695115103874228, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.03294029571401834, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.035934868051656375, 0.5740740740740741, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Aprovados'),
#  Text(0.05390230207748456, 0.7592592592592593, 'idade <= 27.879\ngini = 0.15\nsamples = 98\nvalue = [90.0, 8.0]\nclass = Aprovados'),
#  Text(0.0479131574022085, 0.7222222222222222, 'tipo_residencia_House / apartment <= 0.5\ngini = 0.08\nsamples = 72\nvalue = [69, 3]\nclass = Aprovados'),
#  Text(0.044918585064570464, 0.6851851851851852, 'idade <= 25.284\ngini = 0.278\nsamples = 18\nvalue = [15, 3]\nclass = Aprovados'),
#  Text(0.041924012726932434, 0.6481481481481481, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Aprovados'),
#  Text(0.0479131574022085, 0.6481481481481481, 'idade <= 27.248\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Aprovados'),
#  Text(0.044918585064570464, 0.6111111111111112, 'tempo_emprego <= 0.74\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Reprovados'),
#  Text(0.041924012726932434, 0.5740740740740741, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.0479131574022085, 0.5740740740740741, 'educacao_Higher education <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.044918585064570464, 0.5370370370370371, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.05090772973984653, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.05090772973984653, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Aprovados'),
#  Text(0.05090772973984653, 0.6851851851851852, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]\nclass = Aprovados'),
#  Text(0.05989144675276062, 0.7222222222222222, 'idade <= 28.86\ngini = 0.311\nsamples = 26\nvalue = [21, 5]\nclass = Aprovados'),
#  Text(0.05689687441512259, 0.6851851851851852, 'posse_de_imovel <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = Aprovados'),
#  Text(0.05390230207748456, 0.6481481481481481, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.05989144675276062, 0.6481481481481481, 'tempo_emprego <= 1.837\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Reprovados'),
#  Text(0.05689687441512259, 0.6111111111111112, 'tipo_renda_Working <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Reprovados'),
#  Text(0.05390230207748456, 0.5740740740740741, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Reprovados'),
#  Text(0.05989144675276062, 0.5740740740740741, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.06288601909039865, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.06288601909039865, 0.6851851851851852, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Aprovados'),
#  Text(0.06288601909039865, 0.7962962962962963, 'qtd_filhos <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Aprovados'),
#  Text(0.05989144675276062, 0.7592592592592593, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Aprovados'),
#  Text(0.06588059142803668, 0.7592592592592593, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.08085345311622684, 0.8333333333333334, 'tempo_emprego <= 2.179\ngini = 0.32\nsamples = 50\nvalue = [40, 10]\nclass = Aprovados'),
#  Text(0.07785888077858881, 0.7962962962962963, 'tipo_residencia_Municipal apartment <= 0.5\ngini = 0.13\nsamples = 43\nvalue = [40, 3]\nclass = Aprovados'),
#  Text(0.07486430844095078, 0.7592592592592593, 'tempo_emprego <= 0.64\ngini = 0.091\nsamples = 42\nvalue = [40, 2]\nclass = Aprovados'),
#  Text(0.07186973610331275, 0.7222222222222222, 'sexo <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Aprovados'),
#  Text(0.06887516376567472, 0.6851851851851852, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Aprovados'),
#  Text(0.07486430844095078, 0.6851851851851852, 'estado_civil_Married <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Aprovados'),
#  Text(0.07186973610331275, 0.6481481481481481, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.07785888077858881, 0.6481481481481481, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Aprovados'),
#  Text(0.07785888077858881, 0.7222222222222222, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]\nclass = Aprovados'),
#  Text(0.08085345311622684, 0.7592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.08384802545386487, 0.7962962962962963, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Reprovados'),
#  Text(0.40959038110612017, 0.8703703703703703, 'estado_civil_Widow <= 0.5\ngini = 0.051\nsamples = 3835\nvalue = [3734, 101]\nclass = Aprovados'),
#  Text(0.31637335064570465, 0.8333333333333334, 'possui_fone <= 0.5\ngini = 0.047\nsamples = 3518\nvalue = [3433, 85]\nclass = Aprovados'),
#  Text(0.2545883632790567, 0.7962962962962963, 'qtd_filhos <= 2.5\ngini = 0.036\nsamples = 2444\nvalue = [2399, 45]\nclass = Aprovados'),
#  Text(0.23068149915777653, 0.7592592592592593, 'tempo_emprego <= 1.523\ngini = 0.035\nsamples = 2422\nvalue = [2379, 43]\nclass = Aprovados'),
#  Text(0.20233249110986337, 0.7222222222222222, 'tempo_emprego <= 1.412\ngini = 0.041\nsamples = 1859\nvalue = [1820, 39]\nclass = Aprovados'),
#  Text(0.17408291222159836, 0.6851851851851852, 'estado_civil_Separated <= 0.5\ngini = 0.037\nsamples = 1799\nvalue = [1765, 34]\nclass = Aprovados'),
#  Text(0.1355511884708965, 0.6481481481481481, 'posse_de_imovel <= 0.5\ngini = 0.034\nsamples = 1693\nvalue = [1664, 29]\nclass = Aprovados'),
#  Text(0.09545199326221224, 0.6111111111111112, 'tipo_residencia_Municipal apartment <= 0.5\ngini = 0.06\nsamples = 423\nvalue = [410, 13]\nclass = Aprovados'),
#  Text(0.07561295152536028, 0.5740740740740741, 'tipo_renda_Working <= 0.5\ngini = 0.049\nsamples = 394\nvalue = [384, 10]\nclass = Aprovados'),
#  Text(0.05689687441512259, 0.5370370370370371, 'idade <= 49.211\ngini = 0.035\nsamples = 279\nvalue = [274, 5]\nclass = Aprovados'),
#  Text(0.05390230207748456, 0.5, 'gini = 0.0\nsamples = 76\nvalue = [76, 0]\nclass = Aprovados'),
#  Text(0.05989144675276062, 0.5, 'idade <= 50.399\ngini = 0.048\nsamples = 203\nvalue = [198, 5]\nclass = Aprovados'),
#  Text(0.05689687441512259, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.06288601909039865, 0.46296296296296297, 'idade <= 62.262\ngini = 0.039\nsamples = 202\nvalue = [198, 4]\nclass = Aprovados'),
#  Text(0.05989144675276062, 0.42592592592592593, 'idade <= 62.218\ngini = 0.055\nsamples = 141\nvalue = [137, 4]\nclass = Aprovados'),
#  Text(0.05689687441512259, 0.3888888888888889, 'posse_de_veiculo <= 0.5\ngini = 0.042\nsamples = 140\nvalue = [137, 3]\nclass = Aprovados'),
#  Text(0.04641587123338948, 0.35185185185185186, 'estado_civil_Single / not married <= 0.5\ngini = 0.019\nsamples = 102\nvalue = [101, 1]\nclass = Aprovados'),
#  Text(0.04342129889575145, 0.3148148148148148, 'gini = 0.0\nsamples = 90\nvalue = [90, 0]\nclass = Aprovados'),
#  Text(0.049410443571027515, 0.3148148148148148, 'qt_pessoas_residencia <= 1.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Aprovados'),
#  Text(0.04641587123338948, 0.2777777777777778, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Aprovados'),
#  Text(0.052405015908665545, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.06737787759685569, 0.35185185185185186, 'educacao_Higher education.1 <= 0.5\ngini = 0.1\nsamples = 38\nvalue = [36, 2]\nclass = Aprovados'),
#  Text(0.06138873292157963, 0.3148148148148148, 'idade <= 59.303\ngini = 0.061\nsamples = 32\nvalue = [31, 1]\nclass = Aprovados'),
#  Text(0.058394160583941604, 0.2777777777777778, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Aprovados'),
#  Text(0.06438330525921766, 0.2777777777777778, 'idade <= 59.633\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Aprovados'),
#  Text(0.06138873292157963, 0.24074074074074073, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.06737787759685569, 0.24074074074074073, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Aprovados'),
#  Text(0.07336702227213177, 0.3148148148148148, 'idade <= 55.134\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Aprovados'),
#  Text(0.07037244993449374, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.0763615946097698, 0.2777777777777778, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.06288601909039865, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.06588059142803668, 0.42592592592592593, 'gini = 0.0\nsamples = 61\nvalue = [61, 0]\nclass = Aprovados'),
#  Text(0.09432902863559797, 0.5370370370370371, 'idade <= 60.358\ngini = 0.083\nsamples = 115\nvalue = [110, 5]\nclass = Aprovados'),
#  Text(0.09133445629795994, 0.5, 'tempo_emprego <= 1.236\ngini = 0.068\nsamples = 114\nvalue = [110, 4]\nclass = Aprovados'),
#  Text(0.08235073928504585, 0.46296296296296297, 'posse_de_veiculo <= 0.5\ngini = 0.054\nsamples = 108\nvalue = [105, 3]\nclass = Aprovados'),
#  Text(0.07336702227213177, 0.42592592592592593, 'idade <= 48.093\ngini = 0.025\nsamples = 80\nvalue = [79, 1]\nclass = Aprovados'),
#  Text(0.07037244993449374, 0.3888888888888889, 'gini = 0.0\nsamples = 75\nvalue = [75, 0]\nclass = Aprovados'),
#  Text(0.0763615946097698, 0.3888888888888889, 'idade <= 50.953\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Aprovados'),
#  Text(0.07336702227213177, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.07935616694740782, 0.35185185185185186, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Aprovados'),
#  Text(0.09133445629795994, 0.42592592592592593, 'qtd_filhos <= 1.5\ngini = 0.133\nsamples = 28\nvalue = [26, 2]\nclass = Aprovados'),
#  Text(0.08833988396032191, 0.3888888888888889, 'tempo_emprego <= 0.268\ngini = 0.071\nsamples = 27\nvalue = [26, 1]\nclass = Aprovados'),
#  Text(0.08534531162268388, 0.35185185185185186, 'idade <= 39.67\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.08235073928504585, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.08833988396032191, 0.3148148148148148, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.09133445629795994, 0.35185185185185186, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Aprovados'),
#  Text(0.09432902863559797, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.10031817331087405, 0.46296296296296297, 'tipo_residencia_House / apartment <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Aprovados'),
#  Text(0.09732360097323602, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.10331274564851207, 0.42592592592592593, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.09732360097323602, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.11529103499906419, 0.5740740740740741, 'idade <= 58.247\ngini = 0.185\nsamples = 29\nvalue = [26, 3]\nclass = Aprovados'),
#  Text(0.11229646266142616, 0.5370370370370371, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Aprovados'),
#  Text(0.11828560733670222, 0.5370370370370371, 'idade <= 58.588\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Aprovados'),
#  Text(0.11529103499906419, 0.5, 'estado_civil_Single / not married <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Reprovados'),
#  Text(0.11229646266142616, 0.46296296296296297, 'sexo <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Aprovados'),
#  Text(0.10930189032378813, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.11529103499906419, 0.42592592592592593, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.11828560733670222, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.12128017967434025, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Aprovados'),
#  Text(0.17565038367958075, 0.6111111111111112, 'tipo_renda_State servant <= 0.5\ngini = 0.025\nsamples = 1270\nvalue = [1254, 16]\nclass = Aprovados'),
#  Text(0.16264271008796558, 0.5740740740740741, 'idade <= 57.207\ngini = 0.022\nsamples = 1247\nvalue = [1233, 14]\nclass = Aprovados'),
#  Text(0.14561107991764927, 0.5370370370370371, 'idade <= 57.17\ngini = 0.037\nsamples = 535\nvalue = [525, 10]\nclass = Aprovados'),
#  Text(0.14261650758001124, 0.5, 'tempo_emprego <= 0.521\ngini = 0.033\nsamples = 532\nvalue = [523, 9]\nclass = Aprovados'),
#  Text(0.13250982594048288, 0.46296296296296297, 'tempo_emprego <= 0.508\ngini = 0.056\nsamples = 278\nvalue = [270, 8]\nclass = Aprovados'),
#  Text(0.12128017967434025, 0.42592592592592593, 'idade <= 57.111\ngini = 0.036\nsamples = 270\nvalue = [265, 5]\nclass = Aprovados'),
#  Text(0.11379374883024518, 0.3888888888888889, 'idade <= 36.27\ngini = 0.031\nsamples = 258\nvalue = [254, 4]\nclass = Aprovados'),
#  Text(0.10780460415496912, 0.35185185185185186, 'idade <= 35.333\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Aprovados'),
#  Text(0.10481003181733109, 0.3148148148148148, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Aprovados'),
#  Text(0.11079917649260715, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.11978289350552124, 0.35185185185185186, 'idade <= 51.412\ngini = 0.024\nsamples = 245\nvalue = [242, 3]\nclass = Aprovados'),
#  Text(0.11678832116788321, 0.3148148148148148, 'gini = 0.0\nsamples = 91\nvalue = [91, 0]\nclass = Aprovados'),
#  Text(0.12277746584315927, 0.3148148148148148, 'idade <= 51.542\ngini = 0.038\nsamples = 154\nvalue = [151, 3]\nclass = Aprovados'),
#  Text(0.11978289350552124, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.1257720381807973, 0.2777777777777778, 'qt_pessoas_residencia <= 2.5\ngini = 0.026\nsamples = 153\nvalue = [151, 2]\nclass = Aprovados'),
#  Text(0.11978289350552124, 0.24074074074074073, 'idade <= 55.803\ngini = 0.014\nsamples = 144\nvalue = [143, 1]\nclass = Aprovados'),
#  Text(0.11678832116788321, 0.2037037037037037, 'gini = 0.0\nsamples = 88\nvalue = [88, 0]\nclass = Aprovados'),
#  Text(0.12277746584315927, 0.2037037037037037, 'idade <= 55.826\ngini = 0.035\nsamples = 56\nvalue = [55, 1]\nclass = Aprovados'),
#  Text(0.11978289350552124, 0.16666666666666666, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.1257720381807973, 0.16666666666666666, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]\nclass = Aprovados'),
#  Text(0.13176118285607336, 0.24074074074074073, 'posse_de_veiculo <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Aprovados'),
#  Text(0.12876661051843533, 0.2037037037037037, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.13475575519371139, 0.2037037037037037, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Aprovados'),
#  Text(0.12876661051843533, 0.3888888888888889, 'idade <= 57.115\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Aprovados'),
#  Text(0.1257720381807973, 0.35185185185185186, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.13176118285607336, 0.35185185185185186, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Aprovados'),
#  Text(0.1437394722066255, 0.42592592592592593, 'tempo_emprego <= 0.514\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = Aprovados'),
#  Text(0.14074489986898747, 0.3888888888888889, 'tempo_emprego <= 0.511\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Aprovados'),
#  Text(0.13775032753134944, 0.35185185185185186, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.1437394722066255, 0.35185185185185186, 'qtd_filhos <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Aprovados'),
#  Text(0.14074489986898747, 0.3148148148148148, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.14673404454426353, 0.3148148148148148, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.14673404454426353, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.1527231892195396, 0.46296296296296297, 'tipo_residencia_With parents <= 0.5\ngini = 0.008\nsamples = 254\nvalue = [253, 1]\nclass = Aprovados'),
#  Text(0.14972861688190156, 0.42592592592592593, 'gini = 0.0\nsamples = 239\nvalue = [239, 0]\nclass = Aprovados'),
#  Text(0.15571776155717762, 0.42592592592592593, 'educacao_Secondary / secondary special <= 0.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Aprovados'),
#  Text(0.1527231892195396, 0.3888888888888889, 'tempo_emprego <= 1.032\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.14972861688190156, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.15571776155717762, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.15871233389481565, 0.3888888888888889, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Aprovados'),
#  Text(0.1486056522552873, 0.5, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.17967434025828186, 0.5370370370370371, 'estado_civil_Single / not married <= 0.5\ngini = 0.011\nsamples = 712\nvalue = [708, 4]\nclass = Aprovados'),
#  Text(0.1736851955830058, 0.5, 'idade <= 62.108\ngini = 0.007\nsamples = 609\nvalue = [607, 2]\nclass = Aprovados'),
#  Text(0.17069062324536777, 0.46296296296296297, 'idade <= 62.041\ngini = 0.012\nsamples = 326\nvalue = [324, 2]\nclass = Aprovados'),
#  Text(0.16769605090772974, 0.42592592592592593, 'idade <= 60.285\ngini = 0.006\nsamples = 325\nvalue = [324, 1]\nclass = Aprovados'),
#  Text(0.1647014785700917, 0.3888888888888889, 'gini = 0.0\nsamples = 190\nvalue = [190, 0]\nclass = Aprovados'),
#  Text(0.17069062324536777, 0.3888888888888889, 'idade <= 60.319\ngini = 0.015\nsamples = 135\nvalue = [134, 1]\nclass = Aprovados'),
#  Text(0.16769605090772974, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.1736851955830058, 0.35185185185185186, 'gini = 0.0\nsamples = 134\nvalue = [134, 0]\nclass = Aprovados'),
#  Text(0.1736851955830058, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.17667976792064383, 0.46296296296296297, 'gini = 0.0\nsamples = 283\nvalue = [283, 0]\nclass = Aprovados'),
#  Text(0.18566348493355792, 0.5, 'idade <= 63.789\ngini = 0.038\nsamples = 103\nvalue = [101.0, 2.0]\nclass = Aprovados'),
#  Text(0.18266891259591989, 0.46296296296296297, 'gini = 0.0\nsamples = 73\nvalue = [73, 0]\nclass = Aprovados'),
#  Text(0.18865805727119594, 0.46296296296296297, 'idade <= 63.915\ngini = 0.124\nsamples = 30\nvalue = [28, 2]\nclass = Aprovados'),
#  Text(0.18566348493355792, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.191652629608834, 0.42592592592592593, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]\nclass = Aprovados'),
#  Text(0.18865805727119594, 0.5740740740740741, 'idade <= 47.951\ngini = 0.159\nsamples = 23\nvalue = [21, 2]\nclass = Aprovados'),
#  Text(0.18566348493355792, 0.5370370370370371, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = Aprovados'),
#  Text(0.191652629608834, 0.5370370370370371, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.2126146359723002, 0.6481481481481481, 'idade <= 66.062\ngini = 0.09\nsamples = 106\nvalue = [101, 5]\nclass = Aprovados'),
#  Text(0.20662549129702415, 0.6111111111111112, 'educacao_Lower secondary.1 <= 0.5\ngini = 0.057\nsamples = 103\nvalue = [100, 3]\nclass = Aprovados'),
#  Text(0.20363091895938612, 0.5740740740740741, 'idade <= 38.644\ngini = 0.038\nsamples = 102\nvalue = [100, 2]\nclass = Aprovados'),
#  Text(0.19764177428411006, 0.5370370370370371, 'posse_de_imovel <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Aprovados'),
#  Text(0.19464720194647203, 0.5, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.2006363466217481, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.20962006363466218, 0.5370370370370371, 'idade <= 59.478\ngini = 0.021\nsamples = 93\nvalue = [92, 1]\nclass = Aprovados'),
#  Text(0.20662549129702415, 0.5, 'gini = 0.0\nsamples = 58\nvalue = [58, 0]\nclass = Aprovados'),
#  Text(0.2126146359723002, 0.5, 'idade <= 59.701\ngini = 0.056\nsamples = 35\nvalue = [34, 1]\nclass = Aprovados'),
#  Text(0.20962006363466218, 0.46296296296296297, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.21560920830993824, 0.46296296296296297, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]\nclass = Aprovados'),
#  Text(0.20962006363466218, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.21860378064757627, 0.6111111111111112, 'posse_de_imovel <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Reprovados'),
#  Text(0.21560920830993824, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.2215983529852143, 0.5740740740740741, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.23058206999812839, 0.6851851851851852, 'tempo_emprego <= 1.422\ngini = 0.153\nsamples = 60\nvalue = [55, 5]\nclass = Aprovados'),
#  Text(0.22758749766049036, 0.6481481481481481, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Reprovados'),
#  Text(0.23357664233576642, 0.6481481481481481, 'sexo <= 0.5\ngini = 0.1\nsamples = 57\nvalue = [54, 3]\nclass = Aprovados'),
#  Text(0.23058206999812839, 0.6111111111111112, 'tempo_emprego <= 1.519\ngini = 0.266\nsamples = 19\nvalue = [16, 3]\nclass = Aprovados'),
#  Text(0.22758749766049036, 0.5740740740740741, 'qt_pessoas_residencia <= 3.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = Aprovados'),
#  Text(0.2215983529852143, 0.5370370370370371, 'tempo_emprego <= 1.503\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Aprovados'),
#  Text(0.21860378064757627, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Aprovados'),
#  Text(0.22459292532285233, 0.5, 'idade <= 50.926\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.2215983529852143, 0.46296296296296297, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.22758749766049036, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.23357664233576642, 0.5370370370370371, 'tipo_renda_Working <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.23058206999812839, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.23657121467340445, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.23357664233576642, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.23657121467340445, 0.6111111111111112, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]\nclass = Aprovados'),
#  Text(0.2590305072056897, 0.7222222222222222, 'tipo_residencia_Office apartment <= 0.5\ngini = 0.014\nsamples = 563\nvalue = [559, 4]\nclass = Aprovados'),
#  Text(0.2515440763615946, 0.6851851851851852, 'qt_pessoas_residencia <= 1.5\ngini = 0.011\nsamples = 559\nvalue = [556.0, 3.0]\nclass = Aprovados'),
#  Text(0.24555493168631853, 0.6481481481481481, 'tempo_emprego <= 2.342\ngini = 0.047\nsamples = 83\nvalue = [81, 2]\nclass = Aprovados'),
#  Text(0.2425603593486805, 0.6111111111111112, 'gini = 0.0\nsamples = 58\nvalue = [58, 0]\nclass = Aprovados'),
#  Text(0.2485495040239566, 0.6111111111111112, 'tempo_emprego <= 2.366\ngini = 0.147\nsamples = 25\nvalue = [23, 2]\nclass = Aprovados'),
#  Text(0.24555493168631853, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.2515440763615946, 0.5740740740740741, 'tempo_emprego <= 2.495\ngini = 0.08\nsamples = 24\nvalue = [23, 1]\nclass = Aprovados'),
#  Text(0.2485495040239566, 0.5370370370370371, 'idade <= 38.641\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.24555493168631853, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.2515440763615946, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.25453864869923265, 0.5370370370370371, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Aprovados'),
#  Text(0.25753322103687065, 0.6481481481481481, 'possui_fone_comercial <= 0.5\ngini = 0.004\nsamples = 476\nvalue = [475, 1]\nclass = Aprovados'),
#  Text(0.25453864869923265, 0.6111111111111112, 'gini = 0.0\nsamples = 391\nvalue = [391, 0]\nclass = Aprovados'),
#  Text(0.2605277933745087, 0.6111111111111112, 'idade <= 45.455\ngini = 0.023\nsamples = 85\nvalue = [84, 1]\nclass = Aprovados'),
#  Text(0.25753322103687065, 0.5740740740740741, 'gini = 0.0\nsamples = 63\nvalue = [63, 0]\nclass = Aprovados'),
#  Text(0.2635223657121467, 0.5740740740740741, 'idade <= 46.579\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = Aprovados'),
#  Text(0.2605277933745087, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.26651693804978477, 0.5370370370370371, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = Aprovados'),
#  Text(0.26651693804978477, 0.6851851851851852, 'posse_de_veiculo <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.2635223657121467, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.26951151038742277, 0.6481481481481481, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.2784952274003369, 0.7592592592592593, 'idade <= 34.277\ngini = 0.165\nsamples = 22\nvalue = [20, 2]\nclass = Aprovados'),
#  Text(0.2755006550626989, 0.7222222222222222, 'idade <= 33.305\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Aprovados'),
#  Text(0.2725060827250608, 0.6851851851851852, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Aprovados'),
#  Text(0.2784952274003369, 0.6851851851851852, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.28148979973797494, 0.7222222222222222, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = Aprovados'),
#  Text(0.3781583380123526, 0.7962962962962963, 'tempo_emprego <= 1.284\ngini = 0.072\nsamples = 1074\nvalue = [1034, 40]\nclass = Aprovados'),
#  Text(0.33745087029758564, 0.7592592592592593, 'estado_civil_Separated <= 0.5\ngini = 0.045\nsamples = 781\nvalue = [763, 18]\nclass = Aprovados'),
#  Text(0.30656934306569344, 0.7222222222222222, 'idade <= 57.125\ngini = 0.04\nsamples = 737\nvalue = [722, 15]\nclass = Aprovados'),
#  Text(0.28448437207561295, 0.6851851851851852, 'idade <= 32.616\ngini = 0.02\nsamples = 387\nvalue = [383, 4]\nclass = Aprovados'),
#  Text(0.2755006550626989, 0.6481481481481481, 'idade <= 32.363\ngini = 0.117\nsamples = 32\nvalue = [30, 2]\nclass = Aprovados'),
#  Text(0.2725060827250608, 0.6111111111111112, 'estado_civil_Single / not married <= 0.5\ngini = 0.062\nsamples = 31\nvalue = [30, 1]\nclass = Aprovados'),
#  Text(0.26951151038742277, 0.5740740740740741, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = Aprovados'),
#  Text(0.2755006550626989, 0.5740740740740741, 'educacao_Incomplete higher.1 <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.2725060827250608, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.2784952274003369, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.2784952274003369, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.29346808908852706, 0.6481481481481481, 'idade <= 43.116\ngini = 0.011\nsamples = 355\nvalue = [353, 2]\nclass = Aprovados'),
#  Text(0.290473516750889, 0.6111111111111112, 'idade <= 42.888\ngini = 0.03\nsamples = 132\nvalue = [130, 2]\nclass = Aprovados'),
#  Text(0.287478944413251, 0.5740740740740741, 'idade <= 41.029\ngini = 0.015\nsamples = 131\nvalue = [130, 1]\nclass = Aprovados'),
#  Text(0.28448437207561295, 0.5370370370370371, 'gini = 0.0\nsamples = 116\nvalue = [116, 0]\nclass = Aprovados'),
#  Text(0.290473516750889, 0.5370370370370371, 'idade <= 41.242\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Aprovados'),
#  Text(0.287478944413251, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.29346808908852706, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Aprovados'),
#  Text(0.29346808908852706, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.29646266142616506, 0.6111111111111112, 'gini = 0.0\nsamples = 223\nvalue = [223, 0]\nclass = Aprovados'),
#  Text(0.3286543140557739, 0.6851851851851852, 'idade <= 57.203\ngini = 0.061\nsamples = 350\nvalue = [339, 11]\nclass = Aprovados'),
#  Text(0.3256597417181359, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.33164888639341195, 0.6481481481481481, 'idade <= 60.186\ngini = 0.056\nsamples = 349\nvalue = [339, 10]\nclass = Aprovados'),
#  Text(0.3189219539584503, 0.6111111111111112, 'idade <= 60.067\ngini = 0.132\nsamples = 113\nvalue = [105, 8]\nclass = Aprovados'),
#  Text(0.3084409507767172, 0.5740740740740741, 'idade <= 59.292\ngini = 0.089\nsamples = 107\nvalue = [102, 5]\nclass = Aprovados'),
#  Text(0.3024518061014411, 0.5370370370370371, 'idade <= 57.447\ngini = 0.024\nsamples = 82\nvalue = [81, 1]\nclass = Aprovados'),
#  Text(0.2994572337638031, 0.5, 'idade <= 57.432\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Aprovados'),
#  Text(0.29646266142616506, 0.46296296296296297, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Aprovados'),
#  Text(0.3024518061014411, 0.46296296296296297, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.3054463784390792, 0.5, 'gini = 0.0\nsamples = 73\nvalue = [73, 0]\nclass = Aprovados'),
#  Text(0.31443009545199324, 0.5370370370370371, 'idade <= 59.332\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = Aprovados'),
#  Text(0.31143552311435524, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.3174246677896313, 0.5, 'idade <= 59.811\ngini = 0.159\nsamples = 23\nvalue = [21, 2]\nclass = Aprovados'),
#  Text(0.31443009545199324, 0.46296296296296297, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Aprovados'),
#  Text(0.3204192401272693, 0.46296296296296297, 'idade <= 59.867\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = Aprovados'),
#  Text(0.3174246677896313, 0.42592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.32341381246490736, 0.42592592592592593, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Aprovados'),
#  Text(0.3294029571401834, 0.5740740740740741, 'possui_email <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Aprovados'),
#  Text(0.32640838480254536, 0.5370370370370371, 'posse_de_veiculo <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Reprovados'),
#  Text(0.32341381246490736, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.3294029571401834, 0.5, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Aprovados'),
#  Text(0.3323975294778215, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.3443758188283736, 0.6111111111111112, 'posse_de_imovel <= 0.5\ngini = 0.017\nsamples = 236\nvalue = [234, 2]\nclass = Aprovados'),
#  Text(0.34138124649073553, 0.5740740740740741, 'idade <= 63.856\ngini = 0.075\nsamples = 51\nvalue = [49, 2]\nclass = Aprovados'),
#  Text(0.33838667415309753, 0.5370370370370371, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]\nclass = Aprovados'),
#  Text(0.3443758188283736, 0.5370370370370371, 'idade <= 64.059\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Aprovados'),
#  Text(0.34138124649073553, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.3473703911660116, 0.5, 'posse_de_veiculo <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Aprovados'),
#  Text(0.3443758188283736, 0.46296296296296297, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Aprovados'),
#  Text(0.35036496350364965, 0.46296296296296297, 'educacao_Higher education <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.3473703911660116, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.35335953584128765, 0.42592592592592593, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.3473703911660116, 0.5740740740740741, 'gini = 0.0\nsamples = 185\nvalue = [185, 0]\nclass = Aprovados'),
#  Text(0.36833239752947783, 0.7222222222222222, 'educacao_Higher education <= 0.5\ngini = 0.127\nsamples = 44\nvalue = [41, 3]\nclass = Aprovados'),
#  Text(0.36234325285420177, 0.6851851851851852, 'posse_de_imovel <= 0.5\ngini = 0.053\nsamples = 37\nvalue = [36, 1]\nclass = Aprovados'),
#  Text(0.3593486805165637, 0.6481481481481481, 'idade <= 62.227\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Aprovados'),
#  Text(0.3563541081789257, 0.6111111111111112, 'idade <= 57.919\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.35335953584128765, 0.5740740740740741, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.3593486805165637, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.36234325285420177, 0.6111111111111112, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Aprovados'),
#  Text(0.36533782519183977, 0.6481481481481481, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = Aprovados'),
#  Text(0.3743215422047539, 0.6851851851851852, 'posse_de_imovel <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Aprovados'),
#  Text(0.37132696986711583, 0.6481481481481481, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.3773161145423919, 0.6481481481481481, 'possui_email <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Aprovados'),
#  Text(0.3743215422047539, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.38031068688002995, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Aprovados'),
#  Text(0.4188658057271196, 0.7592592592592593, 'tempo_emprego <= 1.701\ngini = 0.139\nsamples = 293\nvalue = [271.0, 22.0]\nclass = Aprovados'),
#  Text(0.3982781209058581, 0.7222222222222222, 'educacao_Higher education.1 <= 0.5\ngini = 0.402\nsamples = 43\nvalue = [31.0, 12.0]\nclass = Aprovados'),
#  Text(0.39228897623058206, 0.6851851851851852, 'idade <= 42.863\ngini = 0.211\nsamples = 25\nvalue = [22, 3]\nclass = Aprovados'),
#  Text(0.38929440389294406, 0.6481481481481481, 'tipo_renda_Working <= 0.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]\nclass = Aprovados'),
#  Text(0.386299831555306, 0.6111111111111112, 'qtd_filhos <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]\nclass = Aprovados'),
#  Text(0.383305259217668, 0.5740740740740741, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Aprovados'),
#  Text(0.38929440389294406, 0.5740740740740741, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Aprovados'),
#  Text(0.39228897623058206, 0.6111111111111112, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.3952835485682201, 0.6481481481481481, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Aprovados'),
#  Text(0.4042672655811342, 0.6851851851851852, 'qt_pessoas_residencia <= 1.5\ngini = 0.5\nsamples = 18\nvalue = [9, 9]\nclass = Aprovados'),
#  Text(0.4012726932434962, 0.6481481481481481, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Reprovados'),
#  Text(0.40726183791877224, 0.6481481481481481, 'idade <= 40.634\ngini = 0.48\nsamples = 15\nvalue = [9, 6]\nclass = Aprovados'),
#  Text(0.4012726932434962, 0.6111111111111112, 'tipo_renda_Pensioner <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = Reprovados'),
#  Text(0.3982781209058581, 0.5740740740740741, 'sexo <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Reprovados'),
#  Text(0.3952835485682201, 0.5370370370370371, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.4012726932434962, 0.5370370370370371, 'gini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Reprovados'),
#  Text(0.4042672655811342, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.4132509825940483, 0.6111111111111112, 'tipo_renda_Pensioner <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Aprovados'),
#  Text(0.41025641025641024, 0.5740740740740741, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Aprovados'),
#  Text(0.4162455549316863, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.43945349054838106, 0.7222222222222222, 'idade <= 51.188\ngini = 0.077\nsamples = 250\nvalue = [240, 10]\nclass = Aprovados'),
#  Text(0.4282238442822384, 0.6851851851851852, 'educacao_Lower secondary <= 0.5\ngini = 0.039\nsamples = 202\nvalue = [198, 4]\nclass = Aprovados'),
#  Text(0.4252292719446004, 0.6481481481481481, 'tempo_emprego <= 2.532\ngini = 0.03\nsamples = 199\nvalue = [196, 3]\nclass = Aprovados'),
#  Text(0.42223469960696236, 0.6111111111111112, 'gini = 0.0\nsamples = 146\nvalue = [146, 0]\nclass = Aprovados'),
#  Text(0.4282238442822384, 0.6111111111111112, 'estado_civil_Single / not married <= 0.5\ngini = 0.107\nsamples = 53\nvalue = [50, 3]\nclass = Aprovados'),
#  Text(0.42223469960696236, 0.5740740740740741, 'tempo_emprego <= 2.542\ngini = 0.075\nsamples = 51\nvalue = [49, 2]\nclass = Aprovados'),
#  Text(0.41924012726932436, 0.5370370370370371, 'sexo <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Aprovados'),
#  Text(0.4162455549316863, 0.5, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Aprovados'),
#  Text(0.42223469960696236, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.4252292719446004, 0.5370370370370371, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]\nclass = Aprovados'),
#  Text(0.4342129889575145, 0.5740740740740741, 'possui_fone_comercial <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.4312184166198765, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.43720756129515254, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.4312184166198765, 0.6481481481481481, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.45068313681452365, 0.6851851851851852, 'idade <= 51.952\ngini = 0.219\nsamples = 48\nvalue = [42, 6]\nclass = Aprovados'),
#  Text(0.4402021336327906, 0.6481481481481481, 'possui_fone_comercial <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Reprovados'),
#  Text(0.43720756129515254, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.4431967059704286, 0.6111111111111112, 'tempo_emprego <= 2.648\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Reprovados'),
#  Text(0.4402021336327906, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.44619127830806665, 0.5740740740740741, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Reprovados'),
#  Text(0.46116413999625677, 0.6481481481481481, 'estado_civil_Single / not married <= 0.5\ngini = 0.091\nsamples = 42\nvalue = [40, 2]\nclass = Aprovados'),
#  Text(0.4551749953209807, 0.6111111111111112, 'possui_email <= 0.5\ngini = 0.049\nsamples = 40\nvalue = [39, 1]\nclass = Aprovados'),
#  Text(0.4521804229833427, 0.5740740740740741, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]\nclass = Aprovados'),
#  Text(0.45816956765861877, 0.5740740740740741, 'tipo_residencia_Municipal apartment <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.4551749953209807, 0.5370370370370371, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.46116413999625677, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.46715328467153283, 0.6111111111111112, 'posse_de_imovel <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.46415871233389483, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.4701478570091709, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.5028074115665356, 0.8333333333333334, 'sexo <= 0.5\ngini = 0.096\nsamples = 317\nvalue = [301, 16]\nclass = Aprovados'),
#  Text(0.4937301141680704, 0.7962962962962963, 'idade <= 56.97\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Reprovados'),
#  Text(0.49073554183043233, 0.7592592592592593, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.4967246865057084, 0.7592592592592593, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.5118847089650009, 0.7962962962962963, 'tempo_emprego <= 1.355\ngini = 0.08\nsamples = 313\nvalue = [300, 13]\nclass = Aprovados'),
#  Text(0.5027138311809844, 0.7592592592592593, 'tipo_residencia_Municipal apartment <= 0.5\ngini = 0.063\nsamples = 306\nvalue = [296, 10]\nclass = Aprovados'),
#  Text(0.4933557926258656, 0.7222222222222222, 'possui_fone <= 0.5\ngini = 0.059\nsamples = 298\nvalue = [289, 9]\nclass = Aprovados'),
#  Text(0.483623432528542, 0.6851851851851852, 'idade <= 54.982\ngini = 0.075\nsamples = 206\nvalue = [198.0, 8.0]\nclass = Aprovados'),
#  Text(0.47613700168444695, 0.6481481481481481, 'idade <= 54.404\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = Aprovados'),
#  Text(0.4731424293468089, 0.6111111111111112, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Aprovados'),
#  Text(0.47913157402208495, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.49110986337263707, 0.6481481481481481, 'idade <= 66.612\ngini = 0.061\nsamples = 191\nvalue = [185, 6]\nclass = Aprovados'),
#  Text(0.485120718697361, 0.6111111111111112, 'idade <= 60.84\ngini = 0.047\nsamples = 166\nvalue = [162, 4]\nclass = Aprovados'),
#  Text(0.482126146359723, 0.5740740740740741, 'idade <= 60.688\ngini = 0.086\nsamples = 89\nvalue = [85, 4]\nclass = Aprovados'),
#  Text(0.47913157402208495, 0.5370370370370371, 'idade <= 58.514\ngini = 0.068\nsamples = 85\nvalue = [82, 3]\nclass = Aprovados'),
#  Text(0.47613700168444695, 0.5, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]\nclass = Aprovados'),
#  Text(0.482126146359723, 0.5, 'idade <= 58.571\ngini = 0.133\nsamples = 42\nvalue = [39, 3]\nclass = Aprovados'),
#  Text(0.47913157402208495, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.485120718697361, 0.46296296296296297, 'posse_de_veiculo <= 0.5\ngini = 0.049\nsamples = 40\nvalue = [39, 1]\nclass = Aprovados'),
#  Text(0.482126146359723, 0.42592592592592593, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]\nclass = Aprovados'),
#  Text(0.48811529103499907, 0.42592592592592593, 'idade <= 60.125\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.485120718697361, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.49110986337263707, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Aprovados'),
#  Text(0.485120718697361, 0.5370370370370371, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.48811529103499907, 0.5740740740740741, 'gini = 0.0\nsamples = 77\nvalue = [77, 0]\nclass = Aprovados'),
#  Text(0.4970990080479132, 0.6111111111111112, 'posse_de_imovel <= 0.5\ngini = 0.147\nsamples = 25\nvalue = [23, 2]\nclass = Aprovados'),
#  Text(0.4941044357102751, 0.5740740740740741, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.5000935803855512, 0.5740740740740741, 'idade <= 66.727\ngini = 0.08\nsamples = 24\nvalue = [23, 1]\nclass = Aprovados'),
#  Text(0.4970990080479132, 0.5370370370370371, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Aprovados'),
#  Text(0.5030881527231892, 0.5370370370370371, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = Aprovados'),
#  Text(0.5030881527231892, 0.6851851851851852, 'idade <= 65.234\ngini = 0.022\nsamples = 92\nvalue = [91, 1]\nclass = Aprovados'),
#  Text(0.5000935803855512, 0.6481481481481481, 'gini = 0.0\nsamples = 78\nvalue = [78, 0]\nclass = Aprovados'),
#  Text(0.5060827250608273, 0.6481481481481481, 'idade <= 65.748\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Aprovados'),
#  Text(0.5030881527231892, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.5090772973984653, 0.6111111111111112, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Aprovados'),
#  Text(0.5120718697361033, 0.7222222222222222, 'idade <= 61.926\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Aprovados'),
# ...
#  Text(0.8394160583941606, 0.46296296296296297, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.8483997754070747, 0.5, 'qt_pessoas_residencia <= 3.5\ngini = 0.019\nsamples = 305\nvalue = [302.0, 3.0]\nclass = Aprovados'),
#  Text(0.8454052030694367, 0.46296296296296297, 'gini = 0.0\nsamples = 250\nvalue = [250, 0]\nclass = Aprovados'),
#  Text(0.8513943477447127, 0.46296296296296297, 'tempo_emprego <= 6.467\ngini = 0.103\nsamples = 55\nvalue = [52, 3]\nclass = Aprovados'),
#  Text(0.8454052030694367, 0.42592592592592593, 'tempo_emprego <= 6.033\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = Aprovados'),
#  Text(0.8424106307317986, 0.3888888888888889, 'tempo_emprego <= 5.929\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Aprovados'),
#  Text(0.8394160583941606, 0.35185185185185186, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Aprovados'),
#  Text(0.8454052030694367, 0.35185185185185186, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.8483997754070747, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.8573834924199888, 0.42592592592592593, 'tempo_emprego <= 15.352\ngini = 0.044\nsamples = 44\nvalue = [43, 1]\nclass = Aprovados'),
#  Text(0.8543889200823508, 0.3888888888888889, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]\nclass = Aprovados'),
#  Text(0.8603780647576268, 0.3888888888888889, 'tempo_emprego <= 16.048\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Aprovados'),
#  Text(0.8573834924199888, 0.35185185185185186, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.8633726370952648, 0.35185185185185186, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Aprovados'),
#  Text(0.8603780647576268, 0.5740740740740741, 'sexo <= 0.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = Aprovados'),
#  Text(0.8573834924199888, 0.5370370370370371, 'estado_civil_Married <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.8543889200823508, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.8603780647576268, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.8633726370952648, 0.5370370370370371, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = Aprovados'),
#  Text(0.852517312371327, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.855511884708965, 0.6481481481481481, 'gini = 0.0\nsamples = 586\nvalue = [586, 0]\nclass = Aprovados'),
#  Text(0.8723563541081789, 0.6851851851851852, 'tempo_emprego <= 22.473\ngini = 0.038\nsamples = 153\nvalue = [150, 3]\nclass = Aprovados'),
#  Text(0.8663672094329029, 0.6481481481481481, 'idade <= 42.588\ngini = 0.027\nsamples = 146\nvalue = [144, 2]\nclass = Aprovados'),
#  Text(0.8633726370952648, 0.6111111111111112, 'gini = 0.0\nsamples = 93\nvalue = [93, 0]\nclass = Aprovados'),
#  Text(0.8693617817705409, 0.6111111111111112, 'idade <= 42.867\ngini = 0.073\nsamples = 53\nvalue = [51, 2]\nclass = Aprovados'),
#  Text(0.8663672094329029, 0.5740740740740741, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.8723563541081789, 0.5740740740740741, 'gini = 0.0\nsamples = 51\nvalue = [51, 0]\nclass = Aprovados'),
#  Text(0.878345498783455, 0.6481481481481481, 'tempo_emprego <= 22.914\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Aprovados'),
#  Text(0.8753509264458169, 0.6111111111111112, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.881340071121093, 0.6111111111111112, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.881340071121093, 0.7222222222222222, 'idade <= 36.982\ngini = 0.117\nsamples = 16\nvalue = [15, 1]\nclass = Aprovados'),
#  Text(0.878345498783455, 0.6851851851851852, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.884334643458731, 0.6851851851851852, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Aprovados'),
#  Text(0.929206438330526, 0.7592592592592593, 'idade <= 48.181\ngini = 0.036\nsamples = 1548\nvalue = [1520.0, 28.0]\nclass = Aprovados'),
#  Text(0.8993075051469213, 0.7222222222222222, 'idade <= 48.17\ngini = 0.108\nsamples = 140\nvalue = [132, 8]\nclass = Aprovados'),
#  Text(0.8933183604716451, 0.6851851851851852, 'educacao_Incomplete higher.1 <= 0.5\ngini = 0.084\nsamples = 137\nvalue = [131, 6]\nclass = Aprovados'),
#  Text(0.8903237881340071, 0.6481481481481481, 'qtd_filhos <= 3.0\ngini = 0.071\nsamples = 135\nvalue = [130, 5]\nclass = Aprovados'),
#  Text(0.887329215796369, 0.6111111111111112, 'idade <= 47.399\ngini = 0.059\nsamples = 131\nvalue = [127, 4]\nclass = Aprovados'),
#  Text(0.884334643458731, 0.5740740740740741, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Aprovados'),
#  Text(0.8903237881340071, 0.5740740740740741, 'idade <= 48.144\ngini = 0.047\nsamples = 125\nvalue = [122, 3]\nclass = Aprovados'),
#  Text(0.884334643458731, 0.5370370370370371, 'posse_de_veiculo <= 0.5\ngini = 0.034\nsamples = 115\nvalue = [113, 2]\nclass = Aprovados'),
#  Text(0.881340071121093, 0.5, 'gini = 0.0\nsamples = 80\nvalue = [80, 0]\nclass = Aprovados'),
#  Text(0.887329215796369, 0.5, 'educacao_Higher education <= 0.5\ngini = 0.108\nsamples = 35\nvalue = [33, 2]\nclass = Aprovados'),
#  Text(0.884334643458731, 0.46296296296296297, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = Aprovados'),
#  Text(0.8903237881340071, 0.46296296296296297, 'possui_fone <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Aprovados'),
#  Text(0.887329215796369, 0.42592592592592593, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Aprovados'),
#  Text(0.8933183604716451, 0.42592592592592593, 'gini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Aprovados'),
#  Text(0.8963129328092831, 0.5370370370370371, 'idade <= 48.156\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = Aprovados'),
#  Text(0.8933183604716451, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.8993075051469213, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Aprovados'),
#  Text(0.8933183604716451, 0.6111111111111112, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Aprovados'),
#  Text(0.8963129328092831, 0.6481481481481481, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.9052966498221973, 0.6851851851851852, 'estado_civil_Single / not married <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Reprovados'),
#  Text(0.9023020774845593, 0.6481481481481481, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.9082912221598353, 0.6481481481481481, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9591053715141307, 0.7222222222222222, 'idade <= 55.611\ngini = 0.028\nsamples = 1408\nvalue = [1388, 20]\nclass = Aprovados'),
#  Text(0.9451618940670036, 0.6851851851851852, 'idade <= 55.586\ngini = 0.038\nsamples = 990\nvalue = [971, 19]\nclass = Aprovados'),
#  Text(0.9421673217293656, 0.6481481481481481, 'tempo_emprego <= 4.719\ngini = 0.032\nsamples = 987\nvalue = [971, 16]\nclass = Aprovados'),
#  Text(0.9172749391727494, 0.6111111111111112, 'tempo_emprego <= 4.703\ngini = 0.073\nsamples = 132\nvalue = [127, 5]\nclass = Aprovados'),
#  Text(0.9142803668351114, 0.5740740740740741, 'posse_de_veiculo <= 0.5\ngini = 0.045\nsamples = 130\nvalue = [127, 3]\nclass = Aprovados'),
#  Text(0.9082912221598353, 0.5370370370370371, 'qt_pessoas_residencia <= 2.5\ngini = 0.021\nsamples = 95\nvalue = [94, 1]\nclass = Aprovados'),
#  Text(0.9052966498221973, 0.5, 'gini = 0.0\nsamples = 83\nvalue = [83, 0]\nclass = Aprovados'),
#  Text(0.9112857944974734, 0.5, 'idade <= 51.725\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Aprovados'),
#  Text(0.9082912221598353, 0.46296296296296297, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Aprovados'),
#  Text(0.9142803668351114, 0.46296296296296297, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9202695115103874, 0.5370370370370371, 'tempo_emprego <= 3.333\ngini = 0.108\nsamples = 35\nvalue = [33, 2]\nclass = Aprovados'),
#  Text(0.9172749391727494, 0.5, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Aprovados'),
#  Text(0.9232640838480255, 0.5, 'tempo_emprego <= 3.521\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = Aprovados'),
#  Text(0.9202695115103874, 0.46296296296296297, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.9262586561856635, 0.46296296296296297, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Aprovados'),
#  Text(0.9202695115103874, 0.5740740740740741, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Reprovados'),
#  Text(0.9670597042859816, 0.6111111111111112, 'qtd_filhos <= 1.5\ngini = 0.025\nsamples = 855\nvalue = [844, 11]\nclass = Aprovados'),
#  Text(0.9569530226464533, 0.5740740740740741, 'estado_civil_Widow <= 0.5\ngini = 0.023\nsamples = 844\nvalue = [834, 10]\nclass = Aprovados'),
#  Text(0.9457233763803107, 0.5370370370370371, 'idade <= 50.23\ngini = 0.02\nsamples = 797\nvalue = [789.0, 8.0]\nclass = Aprovados'),
#  Text(0.9382369455362156, 0.5, 'idade <= 50.107\ngini = 0.047\nsamples = 206\nvalue = [201, 5]\nclass = Aprovados'),
#  Text(0.9322478008609395, 0.46296296296296297, 'sexo <= 0.5\ngini = 0.02\nsamples = 199\nvalue = [197, 2]\nclass = Aprovados'),
#  Text(0.9292532285233015, 0.42592592592592593, 'idade <= 49.092\ngini = 0.121\nsamples = 31\nvalue = [29, 2]\nclass = Aprovados'),
#  Text(0.9262586561856635, 0.3888888888888889, 'idade <= 48.993\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Aprovados'),
#  Text(0.9232640838480255, 0.35185185185185186, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Aprovados'),
#  Text(0.9292532285233015, 0.35185185185185186, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Reprovados'),
#  Text(0.9322478008609395, 0.3888888888888889, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Aprovados'),
#  Text(0.9352423731985776, 0.42592592592592593, 'gini = 0.0\nsamples = 168\nvalue = [168, 0]\nclass = Aprovados'),
#  Text(0.9442260902114916, 0.46296296296296297, 'tempo_emprego <= 16.656\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Aprovados'),
#  Text(0.9412315178738536, 0.42592592592592593, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.9472206625491297, 0.42592592592592593, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Aprovados'),
#  Text(0.9532098072244057, 0.5, 'idade <= 51.966\ngini = 0.01\nsamples = 591\nvalue = [588.0, 3.0]\nclass = Aprovados'),
#  Text(0.9502152348867677, 0.46296296296296297, 'gini = 0.0\nsamples = 269\nvalue = [269, 0]\nclass = Aprovados'),
#  Text(0.9562043795620438, 0.46296296296296297, 'idade <= 51.982\ngini = 0.018\nsamples = 322\nvalue = [319, 3]\nclass = Aprovados'),
#  Text(0.9532098072244057, 0.42592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9591989518996819, 0.42592592592592593, 'idade <= 52.415\ngini = 0.012\nsamples = 321\nvalue = [319, 2]\nclass = Aprovados'),
#  Text(0.9532098072244057, 0.3888888888888889, 'idade <= 52.36\ngini = 0.071\nsamples = 27\nvalue = [26, 1]\nclass = Aprovados'),
#  Text(0.9502152348867677, 0.35185185185185186, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = Aprovados'),
#  Text(0.9562043795620438, 0.35185185185185186, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9651880965749579, 0.3888888888888889, 'estado_civil_Married <= 0.5\ngini = 0.007\nsamples = 294\nvalue = [293, 1]\nclass = Aprovados'),
#  Text(0.9621935242373199, 0.35185185185185186, 'qt_pessoas_residencia <= 1.5\ngini = 0.027\nsamples = 74\nvalue = [73, 1]\nclass = Aprovados'),
#  Text(0.9591989518996819, 0.3148148148148148, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]\nclass = Aprovados'),
#  Text(0.9651880965749579, 0.3148148148148148, 'tempo_emprego <= 11.008\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Aprovados'),
#  Text(0.9621935242373199, 0.2777777777777778, 'tempo_emprego <= 9.314\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Aprovados'),
#  Text(0.9591989518996819, 0.24074074074074073, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Aprovados'),
#  Text(0.9651880965749579, 0.24074074074074073, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.968182668912596, 0.2777777777777778, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Aprovados'),
#  Text(0.968182668912596, 0.35185185185185186, 'gini = 0.0\nsamples = 220\nvalue = [220, 0]\nclass = Aprovados'),
#  Text(0.968182668912596, 0.5370370370370371, 'tempo_emprego <= 5.658\ngini = 0.081\nsamples = 47\nvalue = [45, 2]\nclass = Aprovados'),
#  Text(0.9651880965749579, 0.5, 'idade <= 50.653\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = Aprovados'),
#  Text(0.9621935242373199, 0.46296296296296297, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Aprovados'),
#  Text(0.968182668912596, 0.46296296296296297, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Aprovados'),
#  Text(0.971177241250234, 0.5, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]\nclass = Aprovados'),
#  Text(0.97716638592551, 0.5740740740740741, 'idade <= 48.884\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Aprovados'),
#  Text(0.974171813587872, 0.5370370370370371, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9801609582631481, 0.5370370370370371, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Aprovados'),
#  Text(0.9481564664046416, 0.6481481481481481, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Reprovados'),
#  Text(0.9730488489612578, 0.6851851851851852, 'tempo_emprego <= 30.623\ngini = 0.005\nsamples = 418\nvalue = [417, 1]\nclass = Aprovados'),
#  Text(0.9700542766236196, 0.6481481481481481, 'gini = 0.0\nsamples = 371\nvalue = [371, 0]\nclass = Aprovados'),
#  Text(0.9760434212988958, 0.6481481481481481, 'tempo_emprego <= 31.042\ngini = 0.042\nsamples = 47\nvalue = [46, 1]\nclass = Aprovados'),
#  Text(0.9730488489612578, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9790379936365338, 0.6111111111111112, 'gini = 0.0\nsamples = 46\nvalue = [46, 0]\nclass = Aprovados'),
#  Text(0.9805352798053528, 0.8703703703703703, 'idade <= 27.182\ngini = 0.159\nsamples = 46\nvalue = [42, 4]\nclass = Aprovados'),
#  Text(0.9730488489612578, 0.8333333333333334, 'posse_de_imovel <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.9700542766236196, 0.7962962962962963, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.9760434212988958, 0.7962962962962963, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.9880217106494479, 0.8333333333333334, 'tempo_emprego <= 16.804\ngini = 0.127\nsamples = 44\nvalue = [41, 3]\nclass = Aprovados'),
#  Text(0.9820325659741718, 0.7962962962962963, 'tempo_emprego <= 6.247\ngini = 0.091\nsamples = 42\nvalue = [40, 2]\nclass = Aprovados'),
#  Text(0.9790379936365338, 0.7592592592592593, 'possui_fone_comercial <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Aprovados'),
#  Text(0.9760434212988958, 0.7222222222222222, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Aprovados'),
#  Text(0.9820325659741718, 0.7222222222222222, 'estado_civil_Married <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Aprovados'),
#  Text(0.9790379936365338, 0.6851851851851852, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.9850271383118099, 0.6851851851851852, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Aprovados'),
#  Text(0.9850271383118099, 0.7592592592592593, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = Aprovados'),
#  Text(0.9940108553247239, 0.7962962962962963, 'tempo_emprego <= 23.768\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Aprovados'),
#  Text(0.9910162829870859, 0.7592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Reprovados'),
#  Text(0.997005427662362, 0.7592592592592593, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Aprovados'),
#  Text(0.8771421135130076, 0.9074074074074074, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Reprovados')]

# %%
ConfusionMatrixDisplay.from_estimator(clf, x_train, y_train, display_labels=['Aprovados', 'Reprovados'])

# %%
predict = clf.predict(x_train)
accuracy_score(y_train, predict)

## Acredito que ele deu tão alto pois existem muitos aprovados, e acaba sendo muito fácil de acertar estes, e os não aprovados acabam sendo mais difíceis de acertar.
## Porém numa análise de crédito isso pode ser um risco muito grande.
# Out:
# 0.991076791076791

# %%
y_train.value_counts(normalize=True)
## Acredito que balancear a base de dados seja deixar os dois valores mais aproximados um do outro, para não ter esse tipo de problema.
## Os aprovados representam quase 98% da base de dados.
# Out:
# mau
# False    0.977435
# True     0.022565
# Name: proportion, dtype: float64

# %% [markdown]
# #### 3) Vamos avaliar o modelo na base de testes
#
# 1. Classifique a base de teste de acordo com a árvore que você treinou no item 2.
# 2. Produza a visualização da matriz de confusão para a base de teste.
# 3. Calcule a acurácia da base de teste. Compare com a acurácia da base de treinamento.
# 4. Treine uma nova árvore com número mínimo de observações por folha de 5 e máximo de profundidade de 10. Use o random_state = 123. Avalie a matriz de classificação. Observe a distribuição da predição - qual a proporção de proponentes foram classificados como 'maus'?
# 5. Como ficaria a acurácia se você classificasse todos os contratos como 'bons'?

# %%
clf = DecisionTreeClassifier(random_state=100)
clf = clf.fit(x_test, y_test)

# %%
ConfusionMatrixDisplay.from_estimator(clf, x_test, y_test, display_labels=['Aprovados', 'Reprovados'])

# %%
predict = clf.predict(x_test)
accuracy_score(y_test, predict)
# Out:
# 0.9943943943943944

# %%
## 4) 
clf = DecisionTreeClassifier(random_state=123, min_samples_leaf=5, max_depth=10)
clf = clf.fit(x_train, y_train)

# %%
ConfusionMatrixDisplay.from_estimator(clf, x_train, y_train, display_labels=['Aprovados', 'Reprovados'])

## A utilização desse modelo, aparentemente seria destrutivo, pois onde ele deveria ser reprovado, acabou sendo aprovado
## Acarretaria em muitas liberações de credito para clientes reprovados.

# %%
predict = clf.predict(x_train)
accuracy_score(y_train, predict)

## Mesmo sendo uma % alta o modelo está inconsistente.
# Out:
# 0.9794079794079794

# %%
print(f'Apenas {round((17+40)/(223+11375), 3)}% dos proponentes foram classificados como reprovados.')
# Out:
# Apenas 0.005% dos proponentes foram classificados como reprovados.

# %%
# 5)
total_contratos = len(y_test)
contratos_bons = (y_test == 0).sum()
acuracia_todos_bons = contratos_bons / total_contratos

# %%
print(f"Acurácia se classificássemos todos como 'bons': {acuracia_todos_bons:.4f}")
# Out:
# Acurácia se classificássemos todos como 'bons': 0.9746
