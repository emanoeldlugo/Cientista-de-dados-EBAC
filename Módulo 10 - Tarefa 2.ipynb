# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('previsao_renda.csv')
data = data.drop('Unnamed: 0', axis =1)
data.columns
# Out:
# Index(['data_ref', 'index', 'sexo', 'posse_de_veiculo', 'posse_de_imovel',
#        'qtd_filhos', 'tipo_renda', 'educacao', 'estado_civil',
#        'tipo_residencia', 'idade', 'tempo_emprego', 'qt_pessoas_residencia',
#        'mau', 'renda'],
#       dtype='object')

# %%
ax = sns.pointplot(x='posse_de_veiculo', y='renda',
                   data=data, dodge=True, errorbar=('ci', 90))

# %%
ax = sns.pointplot(x='posse_de_imovel', y='renda',
                   data=data, dodge=True, errorbar=('ci', 90))

# %%
## Ambas as variáveis discrimina a renda. Na posse de imóvel os pontos são mais próximos porém as linhas de erro padrão
## não chegam no mesmo ponto, e a posse de veículo acaba sendo mais discriminatória ainda na questão de renda, tendo 2 pontos bem distantes.
