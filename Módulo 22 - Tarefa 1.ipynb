# %%
import pandas as pd
import numpy as np

from pandas_datareader import data as web

import plotly.express as px
from plotly import graph_objs

import yfinance as yf

# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
ativos = ['B3SA3.SA', 'BRAV3.SA', 'CMIG4.SA']

dt_ini = '2020-01-01'

df = yf.download(ativos,
                 start=dt_ini)
# Out:
# C:\Users\Emanoel\AppData\Local\Temp\ipykernel_10244\1109496579.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ativos,
# [*********************100%***********************]  3 of 3 completed

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
df = df.stack().reset_index()
df['Amplitude_diaria'] = df['High'] - df['Low']
# Out:
# C:\Users\Emanoel\AppData\Local\Temp\ipykernel_10244\2747942311.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack().reset_index()

# %%
df.head()
# Out:
# Price       Date    Ticker      Close       High        Low       Open  \
# 0     2020-01-02  B3SA3.SA  12.560538  12.560538  12.023145  12.023145
# 1     2020-01-02  CMIG4.SA   3.812403   3.812403   3.751976   3.795923
# 2     2020-01-03  B3SA3.SA  12.198561  12.477002  12.173500  12.376763
# 3     2020-01-03  CMIG4.SA   3.771202   3.823389   3.724508   3.765709
# 4     2020-01-06  B3SA3.SA  12.081619  12.496499  11.995302  12.159583
#
# Price      Volume  Amplitude_diaria
# 0      59905800.0          0.537393
# 1      16377111.0          0.060427
# 2      42734400.0          0.303502
# 3      15603770.0          0.098881
# 4      60060900.0          0.501197

# %%
fig = px.line(df, x='Date', y='Amplitude_diaria', color='Ticker', template='simple_white')

fig.show()

# %% [markdown]
# #### Claramente o ativo que teve mais amplitude foi a BRAV3, por se tratar de uma Small-Cap, tem mais sensibilidade ao mercado.
